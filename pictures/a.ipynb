# %%
import matplotlib.pyplot as plt

# X-axis data: different batch sizes
batch_sizes = [10, 15, 20, 25, 30]

# Note: Data swapped – now we use the originally time data for memory usage
baseline_memory   = [5.129, 6.822, 7.777, 7.996, 7.996]
kivi_memory       = [4.985, 5.686, 6.797, 7.289, 7.783]
kivi_scope_memory = [4.522, 4.979, 5.43, 5.856, 6.671]

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, baseline_memory, marker='o', linestyle='-', label='BASELINE')
plt.plot(batch_sizes, kivi_memory, marker='s', linestyle='-', label='KIVI')
plt.plot(batch_sizes, kivi_scope_memory, marker='^', linestyle='-', label='KIVI+SCOPE')
plt.xlabel('Batch Size', fontsize=12)
plt.ylabel('Memory Usage (GB)', fontsize=12)
plt.title('Memory Usage Comparison\n(meta-llama/Llama-3.2-1B-Instruct seqlen: 64+2048 rs:128)', fontsize=14)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('memory_usage_comparison.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# X-axis data: different batch sizes
batch_sizes = [10, 15, 20, 25, 30]

# Note: Data swapped – now we use the originally memory usage data for time consumption
baseline_time   = [55.45, 59.65, 64.935, 98.347, 119.182]
kivi_time       = [72.1, 67.832, 79.073, 88.57, 96.574]
kivi_scope_time = [61.681, 66.893, 72.78, 86.484, 88.71]

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, baseline_time, marker='o', linestyle='-', label='BASELINE')
plt.plot(batch_sizes, kivi_time, marker='s', linestyle='-', label='KIVI')
plt.plot(batch_sizes, kivi_scope_time, marker='^', linestyle='-', label='KIVI+SCOPE')
plt.xlabel('Batch Size', fontsize=12)
plt.ylabel('Time Consumption (s)', fontsize=12)
plt.title('Time Consumption Comparison\n(meta-llama/Llama-3.2-1B-Instruct seqlen: 64+2048 rs:128)', fontsize=14)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('time_consumption_comparison_64+2048.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Decoding sizes for the x-axis
decoding_size = [4096, 5120, 6144, 7168, 8192, 9216, 10240]

# Memory usage data (in GB)
baseline_memory   = [7.967, 7.980, 7.996, 7.996, 7.996, 7.996, 7.996]
kivi_memory       = [7.996, 7.996, 7.996, 7.996, 7.996, 7.996, 7.996]
kivi_scope_memory = [7.967, 7.887, 7.831, 7.843, 7.805, 7.861, 7.886]

plt.figure(figsize=(8, 6))
plt.plot(decoding_size, baseline_memory, marker='o', linestyle='-', label='BASELINE')
plt.plot(decoding_size, kivi_memory, marker='s', linestyle='-', label='KIVI')
plt.plot(decoding_size, kivi_scope_memory, marker='^', linestyle='-', label='KIVI+SCOPE')

plt.xlabel('Decoding Size (token)', fontsize=12)
plt.ylabel('Memory Usage (GB)', fontsize=12)
plt.title('Memory Usage Comparison\nmeta-llama/Llama-3.2-1B-Instruct seqlen: 1024+X rs:128 RTX4060', fontsize=14)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('memory_usage_1024+X.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Decoding sizes for the x-axis
decoding_size = [4096, 5120, 6144, 7168, 8192, 9216, 10240]

# Time consumption data (in s)
baseline_time   = [143.56, 156.67, 182.37, 261.87, 291.16, 471.851, 525.363]
kivi_time       = [140.18, 160.95, 194.63, 239.10, 239.11, 334.47, 488.69]
kivi_scope_time = [112.78, 145.82, 177.38, 201.83, 227.00, 247.88, 290.904]

plt.figure(figsize=(8, 6))
plt.plot(decoding_size, baseline_time, marker='o', linestyle='-', label='BASELINE')
plt.plot(decoding_size, kivi_time, marker='s', linestyle='-', label='KIVI')
plt.plot(decoding_size, kivi_scope_time, marker='^', linestyle='-', label='KIVI+SCOPE')

plt.xlabel('Decoding Size', fontsize=12)
plt.ylabel('Time Consumption (s)', fontsize=12)
plt.title('Time Consumption Comparison\nmeta-llama/Llama-3.2-1B-Instruct seqlen: 1024+X rs:128 RTX4060', fontsize=14)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('time_consumption_1024+X.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
batch_sizes = [10, 15, 20, 25, 30]
baseline = [369.3417493, 515.0041911, 630.7846308, 520.6056107, 515.5140877]
kivi = [284.0499307, 452.8835948, 518.0023523, 578.0738399, 636.1960776]
kivi_scope = [332.0309334, 459.2408772, 562.7919758, 592.0170205, 692.5938451]

# 使用默认风格
plt.style.use('default')

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(batch_sizes, baseline, marker='o', label='Baseline')
plt.plot(batch_sizes, kivi, marker='s', label='KIVI')
plt.plot(batch_sizes, kivi_scope, marker='^', label='KIVI+SCOPE')

# 添加标签和标题
plt.xlabel('Batch Size')
plt.ylabel('Throughput (tokens/s)')
plt.title('Throughput_comparison_64+2048')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("Throughput_comparison_64+2048.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
decoding_size = [4096, 5120, 6144, 7168, 8192, 9216, 10240]
baseline = [142.658122, 163.4007787, 168.448758, 136.8618017, 140.6786647, 97.65794711, 97.45642537]
kivi = [146.0978742, 159.0556073, 157.8379489, 149.8954412, 171.3019113, 137.7702036, 104.769895]
kivi_scope = [181.5924809, 175.5589082, 173.187507, 177.575187, 180.4405286, 185.8964015, 176.0030801]

# 使用默认风格
plt.style.use('default')

# 创建折线图
plt.figure(figsize=(10, 6))
plt.plot(decoding_size, baseline, marker='o', label='Baseline')
plt.plot(decoding_size, kivi, marker='s', label='KIVI')
plt.plot(decoding_size, kivi_scope, marker='^', label='KIVI+SCOPE')

# 添加坐标轴标签和图形标题
plt.xlabel('Decoding Size')
plt.ylabel('Throughput (tokens/s)')
plt.title('Throughput_comparison_64+2048')

plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("Throughput_comparison_1024+x.png", dpi=300)
plt.show()
